# %%
result1 = 0

def add(num):
	global result1
	result1 = result1 + num
	return result1

print(add(3))
print(add(4))
print(add(5))
# Out:
# 3
# 7
# 12

# %%
result1 = 0
result2 = 0

def add1(num):
	global result1
	result1 = result1 + num
	return result1

def add2(num):
	global result2
	result2 = result2 + num
	return result2

print(add1(3))
print(add2(4))
print(add1(5))
print(add2(6))
# Out:
# 3
# 4
# 8
# 10

# %%
class Calculator:		#class 이름은 파스칼형식(첫글자 대문자)으로 적어야함
	def __init__(self):		#initialize:상태값	class의 변수:property	class의 함수:method	__init__의 매개변수는 self를 해야함
		self.result = 0

	def add(self, num):
		self.result = self.result + num
		return self.result
	
	
cal1 = Calculator()		#self에 들어감
print(cal1.add(3))
print(cal1.add(4))

cal2 = Calculator()		#self.result=0이 각각 따로 갱신
print(cal2.add(5))
print(cal2.add(6))
# Out:
# 3
# 7
# 5
# 11

# %%
class Calculator:		
	def __init__(self):		
		self.result = 0

	def add(self, num):
		self.result = self.result + num
		return self.result
	
	def sub(self, num):
		self.result -= num
		return self.result

print(cal2.add(3))
print(cal2.sub(4))
# Out:
# 14
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 14
#      11 		return self.result
#      13 print(cal2.add(3))
# ---> 14 print(cal2.sub(4))
#
# AttributeError: 'Calculator' object has no attribute 'sub'

# %%
cal3 = Calculator()
print(cal3.add(10))
print(cal3.sub(5))
# Out:
# 10
# 5

# %%
class Calculator:		
	def __init__(self):		
		self.result = 0

	def add(self, num):
		self.result += num
		return self.result
	
	def sub(self, num):
		self.result -= num
		return self.result
	
	def mul(self, num):
		self.result *= num
		return self.result
	
	def div(self, num):
		self.result /= num
		return self.result
	

cal1=Calculator()
cal2=Calculator()

#cal1:+10	-2		*5		/4
print(cal1.add(10))
print(cal1.sub(2))
print(cal1.mul(5))
print(cal1.div(4))

#cal2:+5	*10		-10		/5
print(cal2.add(5))
print(cal2.mul(10))
print(cal2.sub(10))
print(cal2.div(5))
# Out:
# 10
# 8
# 40
# 10.0
# 5
# 50
# 40
# 8.0

# %%
# 객체에 연산할 숫자 지정하기

class FourCal:
	def setdata(self, first, second):
		self.first = first
		self.second = second

	def add(self):
		result = self.first + self.second
		return result
	
cal3 = FourCal()
print(type(cal3))
cal3.setdata(4, 2) #first변수, second변수에 저장

print(cal3.first)
print(cal3.second)
print(cal3.add()) #괄호가 있는거는 method(함수같은거), 없는거는 property(값)
# Out:
# <class '__main__.FourCal'>
# 4
# 2
# 6

# %%
class FourCal:
	def setdata(self, first, second):
		self.first = first
		self.second = second

	def add(self):
		result = self.first + self.second
		return result
	
	def sub(self):
		result = self.first - self.second
		return result
	
	def mul(self):
		result = self.first * self.second
		return result
	
	def div(self):
		result = self.first / self.second
		return result
	

cal4=FourCal()
cal4.setdata(3,4)
print(cal4.first)
print(cal4.first)

cal4.sub()
# Out:
# 3
# 3
# -1

# %%
class FourCal:
	def __init__(self, first, second):
		self.first = first
		self.second = second

	def add(self):
		result = self.first + self.second
		return result
	
	def sub(self):
		result = self.first - self.second
		return result
	
	def mul(self):
		result = self.first * self.second
		return result
	
	def div(self):
		result = self.first / self.second
		return result
	

cal4 = FourCal(10, 20)
print(cal4.first)	
print(cal4.second)

cal4.add()
cal4.div()
# Out:
# 10
# 20
# 0.5

# %%
# 클래스의 상속

class MoreFourCal(FourCal):
	pass

# %%
cal5 = MoreFourCal(4, 2)

# %%
cal5.add()
# Out:
# 6

# %%
class MoreFourCal(FourCal):
	def pow(self):
		result = self.first ** self.second
		return result

# %%
cal6 = MoreFourCal(10, 2)
print(cal6.add())
print(cal6.pow())
# Out:
# 12
# 100

# %%
# 매서드 오버라이딩
class MoreFourCal(FourCal):
	def add(self):
		result = self.first * self.second
		return result
	
cal7 = MoreFourCal(5, 6)
cal7.add()
# Out:
# 30
