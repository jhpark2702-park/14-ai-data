# %%
# 큰따옴표
"Life is too short, you need Python"

#작은따옴표 둘러싸기
'Python is fun'

# 큰따옴표 3개를 연속으로 둘러싸기
"""Life is too short, 
you need Python"""

# 작은따옴표 3개를 연속으로 둘러싸기
'''Life is too short, 
you need Python'''
# Out:
# 'Life is too short, \nyou need Python'

# %%
food = "Python's favorite food is perl"
say='"Python is very easy." he says'

# 역슬래시를 사용하여 작은따옴표와 큰따옴표를 문자열에 포함하기(이스케이프 코드)
food = 'Python\'s favorite food is perl'
say="\"Python is very easy.\" he says"
print(food)
# Out:
# Python's favorite food is perl

# %%
# 줄을 바꾸기 위한 이스케이프 코드 \n
a="Life is too short, \n you need Python"
print(a)
# Out:
# Life is too short,
#  you need Python

# %%
a="Life is too short, \t you need Python"
print(a)
# Out:
# Life is too short, 	 you need Python

# %%
# 문자열 더하기 연산
a="Python"
b=" is fun"

a+b
# Out:
# 'Python is fun'

# %%
#문자열 곱하기 연산
a="Python"
a*3
# Out:
# 'PythonPythonPython'

# %%
print("="*30)
print("Python")
print("="*30)
# Out:
# ==============================
# Python
# ==============================

# %%
#문자열 길이 구하기
a="Life is short, You need Python"
len(a)
# Out:
# 30

# %%
#문자열 인덱싱과 슬라이싱
a="Life is short, You need Python"
a[-1]
# Out:
# 'n'
